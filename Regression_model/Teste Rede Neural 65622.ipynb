# %% [markdown]
# # Rede neural 65622
# Melhor desempenho considerando o critério de maior cos_sim e menor loss

# %%
# Importando as bibliotecas necessarias
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from imblearn.over_sampling import SMOTE
pd.set_option("display.max_rows", 300)
# Out:
# D:\anaconda3\envs\zika\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# D:\anaconda3\envs\zika\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# D:\anaconda3\envs\zika\lib\site-packages\tensorflow\python\framework\dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# D:\anaconda3\envs\zika\lib\site-packages\tensorflow\python\framework\dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# D:\anaconda3\envs\zika\lib\site-packages\tensorflow\python\framework\dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# D:\anaconda3\envs\zika\lib\site-packages\tensorflow\python\framework\dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
class Net(nn.Module):
    def __init__(self, input_size, num_layers, layers_size, output_size):
        super(Net, self).__init__()
        self.num_layers = num_layers

        self.linears = nn.ModuleList([nn.Linear(input_size, layers_size[0])])
        for i in range(0, self.num_layers-2):
            self.linears.extend([nn.Linear(layers_size[i], layers_size[i+1])])              
        self.linears.append(nn.Linear(layers_size[-1], output_size))

    def forward(self, x):
        for layer in self.linears[0:-1]:                   
            x = torch.tanh(layer(x))
        x = self.linears[-1](x)
        return(x)

# %%
testes = pd.read_csv("Loop_Testes_Regressao2.csv")
rede = testes.iloc[np.where(testes["index"]==65622)]
rede
# Out:
#          index                                          net_param  ncamadas  \
# 15622  65622.0  <bound method Module.parameters of Net(\r\n  (...         6
#
#        n_features                                       features_col  \
# 15622          18  [  1  15  41  49  52  58  86  89  94  97  99 1...
#
#                                            features_name  random_state  \
# 15622  ['AgeGroup', 'Analgesic', 'Diabetesmellitus', ...            77
#
#        data_train  data_train_resample  test_loss  test_cos_sim        net
# 15622         124                  280    0.04118      0.873746  net_65622

# %%
print(rede.iloc[0,1])
# Out:
# <bound method Module.parameters of Net(
#   (linears): ModuleList(
#     (0): Linear(in_features=18, out_features=12, bias=True)
#     (1): Linear(in_features=12, out_features=9, bias=True)
#     (2): Linear(in_features=9, out_features=6, bias=True)
#     (3): Linear(in_features=6, out_features=3, bias=True)
#     (4): Linear(in_features=3, out_features=1, bias=True)
#     (5): Linear(in_features=1, out_features=1, bias=True)
#   )
# )>

# %%
data = pd.read_pickle("data_closed_rigid_o")
pf50 = data["PF50_closed_rigid"].values

# Sortear quais caracteristicas usar
n_features = rede.iloc[0,3]
print('Numero de features: %d' % (n_features))
columns =   [1, 15, 41, 49, 52, 58, 86, 89, 94, 97, 99, 111, 117, 123, 135, 152, 167, 173]
print('Colunas: ',columns)

features = data.iloc[:,columns]
features_names = features.columns
print('Features: ',list(features_names))
X = features.values
y = pf50.reshape(len(pf50), 1)

# Separando o dataset em treino e teste
random_state = rede.iloc[0,6]
print('Random State: %d' % (random_state))
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=random_state)

# Histograma dos dados de treino
print("Histogramas dos dados de treino")
for nbins in range(10,1,-1):
    n, bins, patches = plt.hist(y_train, nbins)
    plt.title("Histogramas dos dados de treino - Bins="+str(nbins))
    plt.show()
    if np.min(n)>3:
        break
        
# Indica qual o bin correspondente para cada dado
indices = np.digitize(y_train, bins)

# Arrumar o caso do último valor que não é incluído no último bin
indices[indices>nbins]=nbins
indices = indices.reshape(len(indices),)

# SMOTE - Data Augmentation
data_train = np.hstack([X_train, y_train])
print('Data train: %d' % (data_train.shape[0]))
sm = SMOTE(k_neighbors=np.int(n.min()-1), random_state=42)
data_train_res, indices_res = sm.fit_resample(data_train, indices)
print('Data train resample: %d' % (data_train_res.shape[0]))

# Histograma dos dados de treino resample
print("Histograma dos dados de treino com Resample SMOTE")
n_res, bins_res, patches_res = plt.hist(data_train_res[:,-1], nbins)
plt.title("Histograma dos dados de treino com Resample SMOTE")
plt.show()

# Declarando o dado resample como dado de treino
X_train = data_train_res[:,0:-1]
y_train = data_train_res[:,-1].reshape(data_train_res.shape[0],1)

# Ajustando o escalamento ao dado de TREINAMENTO (fit) e transformando o dado de treinamento
scaler_x = MinMaxScaler(feature_range=(0, 1))
X_train_scaled = scaler_x.fit_transform(X_train)

scaler_y = MinMaxScaler(feature_range=(0, 1))
y_train_scaled = scaler_y.fit_transform(y_train)

torch.manual_seed(1234)

num_layers = rede.iloc[0,2]
print('Number of layers: %d' % (num_layers))
layer_init_size = 12
print('Inicial size layer: %d' % (layer_init_size))
layers_size = np.linspace(layer_init_size, 1, num_layers-1, dtype=int)
print('Layers sizes:', list(layers_size))

net = Net(input_size=X.shape[1], num_layers=num_layers, layers_size=layers_size , output_size=1)
# Out:
# Numero de features: 18
# Colunas:  [1, 15, 41, 49, 52, 58, 86, 89, 94, 97, 99, 111, 117, 123, 135, 152, 167, 173]
# Features:  ['AgeGroup', 'Analgesic', 'Diabetesmellitus', 'Hblocker', 'Hypercholesterolemia', 'Meglitinide', 'Epilepsy', 'Fatty liver', 'Hiatus hernia', 'Inflammation of the tibial nerve', 'Kidney failure', 'Sickle cell anemia', 'Varicose veins of the legs', 'Depression', 'Vasovagal syncope', 'Hypothyroidism_total', 'Internal fixation in the leg', 'PaceMaker']
# Random State: 77
# Histogramas dos dados de treino
# Data train: 124
# Data train resample: 280
# Histograma dos dados de treino com Resample SMOTE
# Number of layers: 6
# Inicial size layer: 12
# Layers sizes: [12, 9, 6, 3, 1]

# %%
# Choose optmizer and loss function
criterion = nn.MSELoss()
optimizer = torch.optim.SGD(net.parameters(), lr = 0.05, momentum = 0.9) # lr = learning rate

# Treinamento utilizando o dado de treino transformado
epochs = 5000
lossr = np.zeros(epochs)

for epoch in range(epochs):
    inputs = torch.autograd.Variable(torch.Tensor(X_train_scaled.astype(np.float32)).float())
    targets = torch.autograd.Variable(torch.Tensor(y_train_scaled.astype(np.float32)).float())

    optimizer.zero_grad()
    out = net(inputs)
    loss = criterion(out, targets)
    loss.backward()
    optimizer.step()

    lossr[epoch] = loss.item()

    if epoch == 0 or (epoch + 1) % 10 == 0:
        print('Epoch %d Loss: %.4f' % (epoch + 1, loss.item()))
# Out:
# Epoch 1 Loss: 2.1708
# Epoch 10 Loss: 0.1199
# Epoch 20 Loss: 0.1741
# Epoch 30 Loss: 0.0933
# Epoch 40 Loss: 0.0827
# Epoch 50 Loss: 0.0788
# Epoch 60 Loss: 0.0755
# Epoch 70 Loss: 0.0757
# Epoch 80 Loss: 0.0751
# Epoch 90 Loss: 0.0752
# Epoch 100 Loss: 0.0751
# Epoch 110 Loss: 0.0751
# Epoch 120 Loss: 0.0751
# Epoch 130 Loss: 0.0751
# Epoch 140 Loss: 0.0751
# Epoch 150 Loss: 0.0751
# Epoch 160 Loss: 0.0751
# Epoch 170 Loss: 0.0751
# Epoch 180 Loss: 0.0751
# Epoch 190 Loss: 0.0751
# Epoch 200 Loss: 0.0751
# Epoch 210 Loss: 0.0751
# Epoch 220 Loss: 0.0751
# Epoch 230 Loss: 0.0751
# Epoch 240 Loss: 0.0751
# Epoch 250 Loss: 0.0751
# Epoch 260 Loss: 0.0751
# Epoch 270 Loss: 0.0751
# Epoch 280 Loss: 0.0751
# Epoch 290 Loss: 0.0751
# Epoch 300 Loss: 0.0751
# Epoch 310 Loss: 0.0751
# Epoch 320 Loss: 0.0751
# Epoch 330 Loss: 0.0751
# Epoch 340 Loss: 0.0751
# Epoch 350 Loss: 0.0751
# Epoch 360 Loss: 0.0751
# Epoch 370 Loss: 0.0751
# Epoch 380 Loss: 0.0751
# Epoch 390 Loss: 0.0751
# Epoch 400 Loss: 0.0751
# Epoch 410 Loss: 0.0751
# Epoch 420 Loss: 0.0751
# Epoch 430 Loss: 0.0751
# Epoch 440 Loss: 0.0751
# Epoch 450 Loss: 0.0751
# Epoch 460 Loss: 0.0751
# Epoch 470 Loss: 0.0751
# Epoch 480 Loss: 0.0751
# Epoch 490 Loss: 0.0751
# Epoch 500 Loss: 0.0751
# Epoch 510 Loss: 0.0751
# Epoch 520 Loss: 0.0751
# Epoch 530 Loss: 0.0751
# Epoch 540 Loss: 0.0751
# Epoch 550 Loss: 0.0751
# Epoch 560 Loss: 0.0751
# Epoch 570 Loss: 0.0751
# Epoch 580 Loss: 0.0751
# Epoch 590 Loss: 0.0751
# Epoch 600 Loss: 0.0751
# Epoch 610 Loss: 0.0751
# Epoch 620 Loss: 0.0751
# Epoch 630 Loss: 0.0751
# Epoch 640 Loss: 0.0751
# Epoch 650 Loss: 0.0751
# Epoch 660 Loss: 0.0751
# Epoch 670 Loss: 0.0751
# Epoch 680 Loss: 0.0751
# Epoch 690 Loss: 0.0751
# Epoch 700 Loss: 0.0751
# Epoch 710 Loss: 0.0751
# Epoch 720 Loss: 0.0751
# Epoch 730 Loss: 0.0751
# Epoch 740 Loss: 0.0751
# Epoch 750 Loss: 0.0751
# Epoch 760 Loss: 0.0751
# Epoch 770 Loss: 0.0751
# Epoch 780 Loss: 0.0751
# Epoch 790 Loss: 0.0751
# Epoch 800 Loss: 0.0751
# Epoch 810 Loss: 0.0751
# Epoch 820 Loss: 0.0751
# Epoch 830 Loss: 0.0751
# Epoch 840 Loss: 0.0751
# Epoch 850 Loss: 0.0751
# Epoch 860 Loss: 0.0751
# Epoch 870 Loss: 0.0751
# Epoch 880 Loss: 0.0751
# Epoch 890 Loss: 0.0751
# Epoch 900 Loss: 0.0751
# Epoch 910 Loss: 0.0751
# Epoch 920 Loss: 0.0751
# Epoch 930 Loss: 0.0751
# Epoch 940 Loss: 0.0751
# Epoch 950 Loss: 0.0751
# Epoch 960 Loss: 0.0751
# Epoch 970 Loss: 0.0751
# Epoch 980 Loss: 0.0751
# Epoch 990 Loss: 0.0751
# Epoch 1000 Loss: 0.0751
# Epoch 1010 Loss: 0.0751
# Epoch 1020 Loss: 0.0751
# Epoch 1030 Loss: 0.0751
# Epoch 1040 Loss: 0.0751
# Epoch 1050 Loss: 0.0751
# Epoch 1060 Loss: 0.0751
# Epoch 1070 Loss: 0.0751
# Epoch 1080 Loss: 0.0751
# Epoch 1090 Loss: 0.0751
# Epoch 1100 Loss: 0.0751
# Epoch 1110 Loss: 0.0751
# Epoch 1120 Loss: 0.0751
# Epoch 1130 Loss: 0.0751
# Epoch 1140 Loss: 0.0751
# Epoch 1150 Loss: 0.0751
# Epoch 1160 Loss: 0.0751
# Epoch 1170 Loss: 0.0751
# Epoch 1180 Loss: 0.0751
# Epoch 1190 Loss: 0.0751
# Epoch 1200 Loss: 0.0751
# Epoch 1210 Loss: 0.0751
# Epoch 1220 Loss: 0.0751
# Epoch 1230 Loss: 0.0751
# Epoch 1240 Loss: 0.0751
# Epoch 1250 Loss: 0.0751
# Epoch 1260 Loss: 0.0751
# Epoch 1270 Loss: 0.0751
# Epoch 1280 Loss: 0.0751
# Epoch 1290 Loss: 0.0751
# Epoch 1300 Loss: 0.0751
# Epoch 1310 Loss: 0.0751
# Epoch 1320 Loss: 0.0751
# Epoch 1330 Loss: 0.0751
# Epoch 1340 Loss: 0.0751
# Epoch 1350 Loss: 0.0751
# Epoch 1360 Loss: 0.0751
# Epoch 1370 Loss: 0.0751
# Epoch 1380 Loss: 0.0751
# Epoch 1390 Loss: 0.0751
# Epoch 1400 Loss: 0.0751
# Epoch 1410 Loss: 0.0751
# Epoch 1420 Loss: 0.0751
# Epoch 1430 Loss: 0.0751
# Epoch 1440 Loss: 0.0751
# Epoch 1450 Loss: 0.0751
# Epoch 1460 Loss: 0.0751
# Epoch 1470 Loss: 0.0751
# Epoch 1480 Loss: 0.0751
# Epoch 1490 Loss: 0.0751
# Epoch 1500 Loss: 0.0751
# Epoch 1510 Loss: 0.0751
# Epoch 1520 Loss: 0.0751
# Epoch 1530 Loss: 0.0751
# Epoch 1540 Loss: 0.0751
# Epoch 1550 Loss: 0.0751
# Epoch 1560 Loss: 0.0751
# Epoch 1570 Loss: 0.0751
# Epoch 1580 Loss: 0.0751
# Epoch 1590 Loss: 0.0751
# Epoch 1600 Loss: 0.0751
# Epoch 1610 Loss: 0.0751
# Epoch 1620 Loss: 0.0751
# Epoch 1630 Loss: 0.0751
# Epoch 1640 Loss: 0.0751
# Epoch 1650 Loss: 0.0751
# Epoch 1660 Loss: 0.0751
# Epoch 1670 Loss: 0.0751
# Epoch 1680 Loss: 0.0751
# Epoch 1690 Loss: 0.0751
# Epoch 1700 Loss: 0.0751
# Epoch 1710 Loss: 0.0751
# Epoch 1720 Loss: 0.0751
# Epoch 1730 Loss: 0.0751
# Epoch 1740 Loss: 0.0751
# Epoch 1750 Loss: 0.0751
# Epoch 1760 Loss: 0.0751
# Epoch 1770 Loss: 0.0751
# Epoch 1780 Loss: 0.0751
# Epoch 1790 Loss: 0.0751
# Epoch 1800 Loss: 0.0751
# Epoch 1810 Loss: 0.0751
# Epoch 1820 Loss: 0.0751
# Epoch 1830 Loss: 0.0751
# Epoch 1840 Loss: 0.0751
# Epoch 1850 Loss: 0.0751
# Epoch 1860 Loss: 0.0751
# Epoch 1870 Loss: 0.0751
# Epoch 1880 Loss: 0.0751
# Epoch 1890 Loss: 0.0751
# Epoch 1900 Loss: 0.0751
# Epoch 1910 Loss: 0.0751
# Epoch 1920 Loss: 0.0751
# Epoch 1930 Loss: 0.0751
# Epoch 1940 Loss: 0.0751
# Epoch 1950 Loss: 0.0751
# Epoch 1960 Loss: 0.0751
# Epoch 1970 Loss: 0.0751
# Epoch 1980 Loss: 0.0751
# Epoch 1990 Loss: 0.0751
# Epoch 2000 Loss: 0.0751
# Epoch 2010 Loss: 0.0751
# Epoch 2020 Loss: 0.0751
# Epoch 2030 Loss: 0.0751
# Epoch 2040 Loss: 0.0751
# Epoch 2050 Loss: 0.0751
# Epoch 2060 Loss: 0.0751
# Epoch 2070 Loss: 0.0751
# Epoch 2080 Loss: 0.0751
# Epoch 2090 Loss: 0.0751
# Epoch 2100 Loss: 0.0751
# Epoch 2110 Loss: 0.0751
# Epoch 2120 Loss: 0.0751
# Epoch 2130 Loss: 0.0751
# Epoch 2140 Loss: 0.0751
# Epoch 2150 Loss: 0.0751
# Epoch 2160 Loss: 0.0751
# Epoch 2170 Loss: 0.0751
# Epoch 2180 Loss: 0.0751
# Epoch 2190 Loss: 0.0751
# Epoch 2200 Loss: 0.0751
# Epoch 2210 Loss: 0.0751
# Epoch 2220 Loss: 0.0751
# Epoch 2230 Loss: 0.0751
# Epoch 2240 Loss: 0.0751
# Epoch 2250 Loss: 0.0751
# Epoch 2260 Loss: 0.0751
# Epoch 2270 Loss: 0.0750
# Epoch 2280 Loss: 0.0750
# Epoch 2290 Loss: 0.0750
# Epoch 2300 Loss: 0.0750
# Epoch 2310 Loss: 0.0750
# Epoch 2320 Loss: 0.0750
# Epoch 2330 Loss: 0.0750
# Epoch 2340 Loss: 0.0750
# Epoch 2350 Loss: 0.0750
# Epoch 2360 Loss: 0.0750
# Epoch 2370 Loss: 0.0750
# Epoch 2380 Loss: 0.0750
# Epoch 2390 Loss: 0.0750
# Epoch 2400 Loss: 0.0750
# Epoch 2410 Loss: 0.0750
# Epoch 2420 Loss: 0.0750
# Epoch 2430 Loss: 0.0750
# Epoch 2440 Loss: 0.0750
# Epoch 2450 Loss: 0.0750
# Epoch 2460 Loss: 0.0750
# Epoch 2470 Loss: 0.0750
# Epoch 2480 Loss: 0.0750
# Epoch 2490 Loss: 0.0750
# Epoch 2500 Loss: 0.0750
# Epoch 2510 Loss: 0.0750
# Epoch 2520 Loss: 0.0750
# Epoch 2530 Loss: 0.0750
# Epoch 2540 Loss: 0.0750
# Epoch 2550 Loss: 0.0750
# Epoch 2560 Loss: 0.0750
# Epoch 2570 Loss: 0.0750
# Epoch 2580 Loss: 0.0750
# Epoch 2590 Loss: 0.0750
# Epoch 2600 Loss: 0.0750
# Epoch 2610 Loss: 0.0750
# Epoch 2620 Loss: 0.0750
# Epoch 2630 Loss: 0.0750
# Epoch 2640 Loss: 0.0750
# Epoch 2650 Loss: 0.0750
# Epoch 2660 Loss: 0.0750
# Epoch 2670 Loss: 0.0750
# Epoch 2680 Loss: 0.0750
# Epoch 2690 Loss: 0.0750
# Epoch 2700 Loss: 0.0750
# Epoch 2710 Loss: 0.0750
# Epoch 2720 Loss: 0.0750
# Epoch 2730 Loss: 0.0750
# Epoch 2740 Loss: 0.0750
# Epoch 2750 Loss: 0.0750
# Epoch 2760 Loss: 0.0750
# Epoch 2770 Loss: 0.0750
# Epoch 2780 Loss: 0.0750
# Epoch 2790 Loss: 0.0750
# Epoch 2800 Loss: 0.0750
# Epoch 2810 Loss: 0.0750
# Epoch 2820 Loss: 0.0750
# Epoch 2830 Loss: 0.0750
# Epoch 2840 Loss: 0.0750
# Epoch 2850 Loss: 0.0750
# Epoch 2860 Loss: 0.0750
# Epoch 2870 Loss: 0.0750
# Epoch 2880 Loss: 0.0750
# Epoch 2890 Loss: 0.0750
# Epoch 2900 Loss: 0.0750
# Epoch 2910 Loss: 0.0750
# Epoch 2920 Loss: 0.0750
# Epoch 2930 Loss: 0.0750
# Epoch 2940 Loss: 0.0750
# Epoch 2950 Loss: 0.0750
# Epoch 2960 Loss: 0.0750
# Epoch 2970 Loss: 0.0750
# Epoch 2980 Loss: 0.0750
# Epoch 2990 Loss: 0.0750
# Epoch 3000 Loss: 0.0750
# Epoch 3010 Loss: 0.0750
# Epoch 3020 Loss: 0.0750
# Epoch 3030 Loss: 0.0750
# Epoch 3040 Loss: 0.0750
# Epoch 3050 Loss: 0.0750
# Epoch 3060 Loss: 0.0750
# Epoch 3070 Loss: 0.0750
# Epoch 3080 Loss: 0.0750
# Epoch 3090 Loss: 0.0750
# Epoch 3100 Loss: 0.0750
# Epoch 3110 Loss: 0.0750
# Epoch 3120 Loss: 0.0750
# Epoch 3130 Loss: 0.0750
# Epoch 3140 Loss: 0.0750
# Epoch 3150 Loss: 0.0750
# Epoch 3160 Loss: 0.0750
# Epoch 3170 Loss: 0.0750
# Epoch 3180 Loss: 0.0750
# Epoch 3190 Loss: 0.0750
# Epoch 3200 Loss: 0.0750
# Epoch 3210 Loss: 0.0750
# Epoch 3220 Loss: 0.0750
# Epoch 3230 Loss: 0.0750
# Epoch 3240 Loss: 0.0749
# Epoch 3250 Loss: 0.0749
# Epoch 3260 Loss: 0.0749
# Epoch 3270 Loss: 0.0749
# Epoch 3280 Loss: 0.0749
# Epoch 3290 Loss: 0.0749
# Epoch 3300 Loss: 0.0749
# Epoch 3310 Loss: 0.0749
# Epoch 3320 Loss: 0.0749
# Epoch 3330 Loss: 0.0749
# Epoch 3340 Loss: 0.0749
# Epoch 3350 Loss: 0.0749
# Epoch 3360 Loss: 0.0749
# Epoch 3370 Loss: 0.0749
# Epoch 3380 Loss: 0.0749
# Epoch 3390 Loss: 0.0749
# Epoch 3400 Loss: 0.0749
# Epoch 3410 Loss: 0.0749
# Epoch 3420 Loss: 0.0748
# Epoch 3430 Loss: 0.0748
# Epoch 3440 Loss: 0.0748
# Epoch 3450 Loss: 0.0748
# Epoch 3460 Loss: 0.0748
# Epoch 3470 Loss: 0.0748
# Epoch 3480 Loss: 0.0748
# Epoch 3490 Loss: 0.0748
# Epoch 3500 Loss: 0.0747
# Epoch 3510 Loss: 0.0747
# Epoch 3520 Loss: 0.0747
# Epoch 3530 Loss: 0.0747
# Epoch 3540 Loss: 0.0746
# Epoch 3550 Loss: 0.0746
# Epoch 3560 Loss: 0.0746
# Epoch 3570 Loss: 0.0745
# Epoch 3580 Loss: 0.0745
# Epoch 3590 Loss: 0.0744
# Epoch 3600 Loss: 0.0744
# Epoch 3610 Loss: 0.0743
# Epoch 3620 Loss: 0.0742
# Epoch 3630 Loss: 0.0741
# Epoch 3640 Loss: 0.0739
# Epoch 3650 Loss: 0.0737
# Epoch 3660 Loss: 0.0735
# Epoch 3670 Loss: 0.0731
# Epoch 3680 Loss: 0.0726
# Epoch 3690 Loss: 0.0719
# Epoch 3700 Loss: 0.0708
# Epoch 3710 Loss: 0.0691
# Epoch 3720 Loss: 0.0668
# Epoch 3730 Loss: 0.0646
# Epoch 3740 Loss: 0.0635
# Epoch 3750 Loss: 0.0633
# Epoch 3760 Loss: 0.0631
# Epoch 3770 Loss: 0.0628
# Epoch 3780 Loss: 0.0626
# Epoch 3790 Loss: 0.0624
# Epoch 3800 Loss: 0.0622
# Epoch 3810 Loss: 0.0621
# Epoch 3820 Loss: 0.0619
# Epoch 3830 Loss: 0.0617
# Epoch 3840 Loss: 0.0615
# Epoch 3850 Loss: 0.0613
# Epoch 3860 Loss: 0.0611
# Epoch 3870 Loss: 0.0609
# Epoch 3880 Loss: 0.0607
# Epoch 3890 Loss: 0.0605
# Epoch 3900 Loss: 0.0603
# Epoch 3910 Loss: 0.0601
# Epoch 3920 Loss: 0.0598
# Epoch 3930 Loss: 0.0596
# Epoch 3940 Loss: 0.0593
# Epoch 3950 Loss: 0.0590
# Epoch 3960 Loss: 0.0587
# Epoch 3970 Loss: 0.0584
# Epoch 3980 Loss: 0.0580
# Epoch 3990 Loss: 0.0575
# Epoch 4000 Loss: 0.0569
# Epoch 4010 Loss: 0.0563
# Epoch 4020 Loss: 0.0554
# Epoch 4030 Loss: 0.0543
# Epoch 4040 Loss: 0.0530
# Epoch 4050 Loss: 0.0515
# Epoch 4060 Loss: 0.0498
# Epoch 4070 Loss: 0.0485
# Epoch 4080 Loss: 0.0476
# Epoch 4090 Loss: 0.0472
# Epoch 4100 Loss: 0.0471
# Epoch 4110 Loss: 0.0470
# Epoch 4120 Loss: 0.0470
# Epoch 4130 Loss: 0.0469
# Epoch 4140 Loss: 0.0468
# Epoch 4150 Loss: 0.0468
# Epoch 4160 Loss: 0.0468
# Epoch 4170 Loss: 0.0467
# Epoch 4180 Loss: 0.0467
# Epoch 4190 Loss: 0.0466
# Epoch 4200 Loss: 0.0466
# Epoch 4210 Loss: 0.0466
# Epoch 4220 Loss: 0.0465
# Epoch 4230 Loss: 0.0465
# Epoch 4240 Loss: 0.0465
# Epoch 4250 Loss: 0.0465
# Epoch 4260 Loss: 0.0464
# Epoch 4270 Loss: 0.0464
# Epoch 4280 Loss: 0.0464
# Epoch 4290 Loss: 0.0463
# Epoch 4300 Loss: 0.0463
# Epoch 4310 Loss: 0.0463
# Epoch 4320 Loss: 0.0463
# Epoch 4330 Loss: 0.0462
# Epoch 4340 Loss: 0.0462
# Epoch 4350 Loss: 0.0462
# Epoch 4360 Loss: 0.0461
# Epoch 4370 Loss: 0.0461
# Epoch 4380 Loss: 0.0461
# Epoch 4390 Loss: 0.0461
# Epoch 4400 Loss: 0.0460
# Epoch 4410 Loss: 0.0460
# Epoch 4420 Loss: 0.0460
# Epoch 4430 Loss: 0.0459
# Epoch 4440 Loss: 0.0459
# Epoch 4450 Loss: 0.0459
# Epoch 4460 Loss: 0.0458
# Epoch 4470 Loss: 0.0458
# Epoch 4480 Loss: 0.0458
# Epoch 4490 Loss: 0.0457
# Epoch 4500 Loss: 0.0457
# Epoch 4510 Loss: 0.0457
# Epoch 4520 Loss: 0.0456
# Epoch 4530 Loss: 0.0456
# Epoch 4540 Loss: 0.0456
# Epoch 4550 Loss: 0.0455
# Epoch 4560 Loss: 0.0455
# Epoch 4570 Loss: 0.0455
# Epoch 4580 Loss: 0.0454
# Epoch 4590 Loss: 0.0454
# Epoch 4600 Loss: 0.0453
# Epoch 4610 Loss: 0.0453
# Epoch 4620 Loss: 0.0452
# Epoch 4630 Loss: 0.0452
# Epoch 4640 Loss: 0.0452
# Epoch 4650 Loss: 0.0451
# Epoch 4660 Loss: 0.0451
# Epoch 4670 Loss: 0.0450
# Epoch 4680 Loss: 0.0450
# Epoch 4690 Loss: 0.0449
# Epoch 4700 Loss: 0.0449
# Epoch 4710 Loss: 0.0448
# Epoch 4720 Loss: 0.0448
# Epoch 4730 Loss: 0.0447
# Epoch 4740 Loss: 0.0447
# Epoch 4750 Loss: 0.0446
# Epoch 4760 Loss: 0.0446
# Epoch 4770 Loss: 0.0445
# Epoch 4780 Loss: 0.0445
# Epoch 4790 Loss: 0.0444
# Epoch 4800 Loss: 0.0444
# Epoch 4810 Loss: 0.0443
# Epoch 4820 Loss: 0.0443
# Epoch 4830 Loss: 0.0443
# Epoch 4840 Loss: 0.0442
# Epoch 4850 Loss: 0.0442
# Epoch 4860 Loss: 0.0441
# Epoch 4870 Loss: 0.0441
# Epoch 4880 Loss: 0.0440
# Epoch 4890 Loss: 0.0440
# Epoch 4900 Loss: 0.0439
# Epoch 4910 Loss: 0.0439
# Epoch 4920 Loss: 0.0439
# Epoch 4930 Loss: 0.0438
# Epoch 4940 Loss: 0.0438
# Epoch 4950 Loss: 0.0438
# Epoch 4960 Loss: 0.0437
# Epoch 4970 Loss: 0.0437
# Epoch 4980 Loss: 0.0437
# Epoch 4990 Loss: 0.0436
# Epoch 5000 Loss: 0.0436

# %%
epoch = np.arange(0, epochs)
plt.plot(epoch,lossr)
plt.show()

# Transformando o dado de teste
X_test_scaled = scaler_x.fit_transform(X_test)
y_test_scaled = scaler_y.fit_transform(y_test)

# Avaliando a acurácia do modelo utilizando os dados de teste transformados
inputs = torch.autograd.Variable(torch.Tensor(X_test_scaled.astype(np.float32)).float())
targets = torch.autograd.Variable(torch.Tensor(y_test_scaled.astype(np.float32)).float())

optimizer.zero_grad()
out = net(inputs)
loss = criterion(out, targets)
loss.backward()
optimizer.step()

predicted = out.data

print('Teste Loss: %.4f' % (loss.item()))

# Implementando a métrica do Cosine Similarity
cos = nn.CosineSimilarity(dim=0, eps=1e-6)
cos_sim = cos(targets, predicted)
print('Teste Cosine Similarity: %.4f' % (cos_sim.item()))

ninput = np.arange(len(X_test))
plt.figure()
plt.plot(ninput, y_test_scaled, '-*', label = 'target')
plt.plot(ninput, predicted.numpy(), '-+', label = 'predicted')
plt.title('Dados Normalizados')
plt.legend()
plt.show()

# Fazendo a transformação inversa para desnormalizar o dado de teste
predicted_desnorm = scaler_y.inverse_transform(predicted.numpy())
target_desnorm = scaler_y.inverse_transform(y_test_scaled)

plt.figure()
plt.plot(ninput, target_desnorm, '-*', label = 'target')
plt.plot(ninput, predicted_desnorm, '-+', label = 'predicted')
plt.title('Desnormalizado target_desnorm')
plt.legend()
plt.show()
# Out:
# Teste Loss: 0.0412
# Teste Cosine Similarity: 0.8737

# %%
plt.figure()
plt.plot(np.log10(epoch),lossr)
plt.title("Taxa de Perda x Epochs")
plt.xlabel("Log(Epochs)")
plt.ylabel("Loss [$Hz^2$]")
plt.show()
# Out:
# D:\anaconda3\envs\zika\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in log10

# %% [markdown]
# ## Pela análise dos gráficos, pode-se perceber que a rede atingiu dois níveis (valores extremos).
# ## Próximos passos:
# - Mudar a função de ativação (tanh para relu)
